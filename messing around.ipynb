# %%
import torch

device = torch.accelerator.current_accelerator() if torch.accelerator.is_available() else torch.device('cpu')
device
# Out:
# device(type='mps')

# %%
print(torch.accelerator.device_count())
# Out:
# 1

# %%
print(torch.accelerator.current_accelerator())
# Out:
# mps

# %%
torch.accelerator.max_memory_allocated()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 torch.accelerator.max_memory_allocated()
#
# File ~/anaconda3/lib/python3.13/site-packages/torch/accelerator/memory.py:137, in max_memory_allocated(device_index)
#     123 def max_memory_allocated(device_index: _device_t = None, /) -> int:
#     124     r"""Return the current :ref:`accelerator<accelerators>` maximum device memory occupied by tensors
#     125     in bytes for a given device index.
#     126
#    (...)
#     135             :ref:`accelerator<accelerators>` device type.
#     136     """
# --> 137     return memory_stats(device_index).get("allocated_bytes.all.peak", 0)
#
# File ~/anaconda3/lib/python3.13/site-packages/torch/accelerator/memory.py:91, in memory_stats(device_index)
#      33 def memory_stats(device_index: _device_t = None, /) -> OrderedDict[str, Any]:
#      34     r"""Return a dictionary of accelerator device memory allocator statistics for a given device index.
#      35
#      36     The return value of this function is a dictionary of statistics, each of
#    (...)
#      89             :ref:`accelerator<accelerators>` device type.
#      90     """
# ---> 91     if not torch._C._accelerator_isAllocatorInitialized():
#      92         return OrderedDict()
#      93     device_index = _get_device_index(device_index, optional=True)
#
# RuntimeError: device_allocator INTERNAL ASSERT FAILED at "/Users/runner/work/pytorch/pytorch/pytorch/c10/core/CachingDeviceAllocator.h":110, please report a bug to PyTorch. Allocator for mps is not a DeviceAllocator.
